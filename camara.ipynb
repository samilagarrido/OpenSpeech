# %%
import requests
from bs4 import BeautifulSoup

# %%
url = requests.get("https://www.camara.leg.br/internet/SitaqWeb/ResultadoPesquisaDiscursos.asp?txOrador=&txPartido=&txUF=&dtInicio=28%2F03%2F2022&dtFim=28%2F04%2F2022&txSessao=&listaTipoFala=&listaFaseSessao=&listaTipoInterv=&txAparteante=&txTexto=&txSumario=&txIndexacao=&BasePesq=plenario&CampoOrdenacao=dtSessao&PageSize=20&TipoOrdenacao=ASC&btnPesqAvan=Pesquisar")

content = url.content

soup = BeautifulSoup(content, 'html.parser')

# %%
# título
title = soup.find("h1")
print(title.text)
# Out:
# Discursos e Notas Taquigráficas

# %%
body = soup.find("tbody", attrs={"class": "coresAlternadas"})
print(len(body))
print(body.text)
# Out:
# 81
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AFONSO FLORENCE, PT-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         AGUINALDO RIBEIRO, PP-PB
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         ANTONIO BRITO, PSD-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         ARLINDO CHINAGLIA, PT-SP
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         ARLINDO CHINAGLIA, PT-SP
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         BIRA DO PINDARÉ, PSB-MA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         CARMEN ZANOTTO, CIDADANIA-SC
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         CHRISTIANE DE SOUZA YARED, PL-PR
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         CLAUDIO CAJADO, PP-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         CLAUDIO CAJADO, PP-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022
#
#
#
#
#
#
#
#
#
# 28/04/2022
# 013.4.56.N
# ORDEM DO DIA
#
#
#
#
#
#
#
#                         CLAUDIO CAJADO, PP-BA
#
#
# 12h37
#
#
# 	DCN 29/04/2022

# %%
'''    result = columns.replace('\n', '')
    result = columns.replace('\t', '')'''
# Out:
# "    result = columns.replace('\n', '')\n    result = columns.replace('\t', '')"

# %%
body_list = []
for item in soup.find("tbody", attrs={"class": "coresAlternadas"}):
    print(item)
# Out:
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=3
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img1" onclick="DoClick('Suma1')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma1" name="Suma1" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=23
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img2" onclick="DoClick('Suma2')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma2" name="Suma2" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=27
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img3" onclick="DoClick('Suma3')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma3" name="Suma3" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=33
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img4" onclick="DoClick('Suma4')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma4" name="Suma4" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=40
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img5" onclick="DoClick('Suma5')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma5" name="Suma5" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=41
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img6" onclick="DoClick('Suma6')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma6" name="Suma6" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=37
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img7" onclick="DoClick('Suma7')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma7" name="Suma7" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=46
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img8" onclick="DoClick('Suma8')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma8" name="Suma8" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=48
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img9" onclick="DoClick('Suma9')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma9" name="Suma9" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=52
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img10" onclick="DoClick('Suma10')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma10" name="Suma10" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=6
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AGUINALDO RIBEIRO, PP-PB
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img11" onclick="DoClick('Suma11')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AGUINALDO RIBEIRO, PP-PB
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma11" name="Suma11" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=1
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=ANTONIO BRITO, PSD-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img12" onclick="DoClick('Suma12')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         ANTONIO BRITO, PSD-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma12" name="Suma12" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=2
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=ARLINDO CHINAGLIA, PT-SP
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img13" onclick="DoClick('Suma13')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         ARLINDO CHINAGLIA, PT-SP
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma13" name="Suma13" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=5
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=ARLINDO CHINAGLIA, PT-SP
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img14" onclick="DoClick('Suma14')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         ARLINDO CHINAGLIA, PT-SP
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma14" name="Suma14" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=14
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=BIRA DO PINDARÉ, PSB-MA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img15" onclick="DoClick('Suma15')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         BIRA DO PINDARÉ, PSB-MA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma15" name="Suma15" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=22
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CARMEN ZANOTTO, CIDADANIA-SC
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img16" onclick="DoClick('Suma16')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CARMEN ZANOTTO, CIDADANIA-SC
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma16" name="Suma16" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=10
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CHRISTIANE DE SOUZA YARED, PL-PR
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img17" onclick="DoClick('Suma17')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CHRISTIANE DE SOUZA YARED, PL-PR
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma17" name="Suma17" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=21
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CLAUDIO CAJADO, PP-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img18" onclick="DoClick('Suma18')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CLAUDIO CAJADO, PP-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma18" name="Suma18" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=18
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CLAUDIO CAJADO, PP-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img19" onclick="DoClick('Suma19')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CLAUDIO CAJADO, PP-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="even" id="Suma19" name="Suma19" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>
#
#
# <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=42
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CLAUDIO CAJADO, PP-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img20" onclick="DoClick('Suma20')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CLAUDIO CAJADO, PP-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>
#
#
# <tr class="odd" id="Suma20" name="Suma20" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>

# %%
body = soup.find("tbody", attrs={"class": "coresAlternadas"}).get_text()
body
# Out:
# '\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AFONSO FLORENCE, PT-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        AGUINALDO RIBEIRO, PP-PB\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        ANTONIO BRITO, PSD-BA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        ARLINDO CHINAGLIA, PT-SP\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        ARLINDO CHINAGLIA, PT-SP\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        BIRA DO PINDARÉ, PSB-MA\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013.4.56.N     \nORDEM DO DIA                  \n\n\n\n\n\n\n\r\n                        CARMEN ZANOTTO, CIDADANIA-SC\r\n                    \n\r\n12h37\t\t\t\t\t\t\t\t\r\n\t\t\t\t\n\r\n\tDCN 29/04/2022\r\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n28/04/2022\n013 ...

# %% [markdown]
# ## 2) Colunas

# %%
columns_list = []
for item in soup.find("thead"):
    columns_list.append(item.get_text())
columns_list = columns_list[1].split('\n')[1:8]
columns_list
# Out:
# ['Data', 'Sessão', 'Fase', 'Discurso', 'Sumário', 'Orador', 'Hora']

# %%
# Out:
# ['Data', 'Sessão', 'Fase', 'Discurso', 'Sumário', 'Orador', 'Hora']

# %%
item = soup.find_all("tr")
print(item)
# Out:
# [<tr>
# <th scope="col" width="8%">Data</th>
# <th scope="col" width="8%">Sessão</th>
# <th scope="col" width="8%">Fase</th>
# <th scope="col" title="Clique na imagem para visualizar a íntegrar do Discurso." width="3%">Discurso</th>
# <th scope="col" title="Clique na imagem para visualizar o Sumário." width="3%">Sumário</th>
# <th scope="col" width="50%">Orador</th>
# <th scope="col" width="2%">Hora</th>
# <th scope="col" width="18%">Publicação</th>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=3
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img1" onclick="DoClick('Suma1')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma1" name="Suma1" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=23
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img2" onclick="DoClick('Suma2')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma2" name="Suma2" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=27
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img3" onclick="DoClick('Suma3')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma3" name="Suma3" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=33
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img4" onclick="DoClick('Suma4')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma4" name="Suma4" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=40
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img5" onclick="DoClick('Suma5')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma5" name="Suma5" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=41
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img6" onclick="DoClick('Suma6')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma6" name="Suma6" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=37
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img7" onclick="DoClick('Suma7')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma7" name="Suma7" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=46
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img8" onclick="DoClick('Suma8')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma8" name="Suma8" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=48
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img9" onclick="DoClick('Suma9')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma9" name="Suma9" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=52
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AFONSO FLORENCE, PT-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img10" onclick="DoClick('Suma10')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AFONSO FLORENCE, PT-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma10" name="Suma10" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=6
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=AGUINALDO RIBEIRO, PP-PB
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img11" onclick="DoClick('Suma11')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         AGUINALDO RIBEIRO, PP-PB
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma11" name="Suma11" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=1
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=ANTONIO BRITO, PSD-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img12" onclick="DoClick('Suma12')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         ANTONIO BRITO, PSD-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma12" name="Suma12" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=2
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=ARLINDO CHINAGLIA, PT-SP
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img13" onclick="DoClick('Suma13')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         ARLINDO CHINAGLIA, PT-SP
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma13" name="Suma13" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=5
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=ARLINDO CHINAGLIA, PT-SP
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img14" onclick="DoClick('Suma14')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         ARLINDO CHINAGLIA, PT-SP
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma14" name="Suma14" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=14
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=BIRA DO PINDARÉ, PSB-MA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img15" onclick="DoClick('Suma15')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         BIRA DO PINDARÉ, PSB-MA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma15" name="Suma15" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=22
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CARMEN ZANOTTO, CIDADANIA-SC
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img16" onclick="DoClick('Suma16')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CARMEN ZANOTTO, CIDADANIA-SC
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma16" name="Suma16" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=10
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CHRISTIANE DE SOUZA YARED, PL-PR
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img17" onclick="DoClick('Suma17')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CHRISTIANE DE SOUZA YARED, PL-PR
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma17" name="Suma17" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=21
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CLAUDIO CAJADO, PP-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img18" onclick="DoClick('Suma18')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CLAUDIO CAJADO, PP-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma18" name="Suma18" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="even">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=18
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CLAUDIO CAJADO, PP-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img19" onclick="DoClick('Suma19')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CLAUDIO CAJADO, PP-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="even" id="Suma19" name="Suma19" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>, <tr class="odd">
# <td>28/04/2022</td>
# <td>013.4.56.N     </td>
# <td>ORDEM DO DIA                  </td>
# <td align="center">
# <a href="TextoHTML.asp?etapa=5
# 							&amp;nuSessao=013.4.56.N
# 							&amp;nuQuarto=0
# 							&amp;nuOrador=0
# 							&amp;nuInsercao=42
# 							&amp;dtHorarioQuarto=12:37
# 							&amp;sgFaseSessao=OD
# 							&amp;Data=28/04/2022
# 							&amp;txApelido=CLAUDIO CAJADO, PP-BA
# 							&amp;txFaseSessao=Ordem do Dia
# 							&amp;txTipoSessao=Extraordinária - CN
# 							&amp;dtHoraQuarto=12:37
# 							&amp;txEtapa=" title="Íntegra do Discurso"><span class="glyphicon glyphicon-file"></span></a>
# </td>
# <td align="center">
# <a class="linkSumario" id="Img20" onclick="DoClick('Suma20')" style="cursor:pointer" title="Sumário: "><span class="glyphicon glyphicon-zoom-in"></span></a>
# </td>
# <td>
#                         CLAUDIO CAJADO, PP-BA
#                     </td>
# <td>
# 12h37
# 				</td>
# <td>
# 	DCN 29/04/2022
# 									<!-- a href="#" OnClick="MostraImagem2('','','')">
#
# 										</a <span class="glyphicon glyphicon-list-alt"></span>-->
# <!-- a href="http://legis.senado.leg.br/diarios/BuscaDiario?tipDiario=2&datDiario=&paginaDireta=">
#
# 							</a> <span class="glyphicon glyphicon-list-alt"></span> -->
# </td>
# </tr>, <tr class="odd" id="Suma20" name="Suma20" style="display: none">
# <td class="Sumario" colspan="8">
# </td>
# </tr>]
